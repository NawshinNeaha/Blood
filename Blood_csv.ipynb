# %% [markdown]
# <a href="https://colab.research.google.com/github/NawshinNeaha/Blood/blob/main/Blood_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/blood.csv')
df
# Out:
#      Recency  Frequency  Monetary  Time  Class
# 0          2         50     12500    98      1
# 1          0         13      3250    28      1
# 2          1         16      4000    35      1
# 3          2         20      5000    45      1
# 4          1         24      6000    77      0
# ..       ...        ...       ...   ...    ...
# 743       23          2       500    38      0
# 744       21          2       500    52      0
# 745       23          3       750    62      0
# 746       39          1       250    39      0
# 747       72          1       250    72      0
#
# [748 rows x 5 columns]

# %%
df.head(10)
# Out:
#    Recency  Frequency  Monetary  Time  Class
# 0        2         50     12500    98      1
# 1        0         13      3250    28      1
# 2        1         16      4000    35      1
# 3        2         20      5000    45      1
# 4        1         24      6000    77      0
# 5        4          4      1000     4      0
# 6        2          7      1750    14      1
# 7        1         12      3000    35      0
# 8        2          9      2250    22      1
# 9        5         46     11500    98      1

# %%
df.tail(10)
# Out:
#      Recency  Frequency  Monetary  Time  Class
# 738       23          1       250    23      0
# 739       23          4      1000    52      0
# 740       23          1       250    23      0
# 741       23          7      1750    88      0
# 742       16          3       750    86      0
# 743       23          2       500    38      0
# 744       21          2       500    52      0
# 745       23          3       750    62      0
# 746       39          1       250    39      0
# 747       72          1       250    72      0

# %%
df.shape
# Out:
# (748, 5)

# %%
df.Class.head(10)
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# 5    0
# 6    1
# 7    0
# 8    1
# 9    1
# Name: Class, dtype: int64

# %%
df.Recency
# Out:
# 0       2
# 1       0
# 2       1
# 3       2
# 4       1
#        ..
# 743    23
# 744    21
# 745    23
# 746    39
# 747    72
# Name: Recency, Length: 748, dtype: int64

# %%
df.bool
# Out:
# <bound method NDFrame.bool of      Recency  Frequency  Monetary  Time  Class
# 0          2         50     12500    98      1
# 1          0         13      3250    28      1
# 2          1         16      4000    35      1
# 3          2         20      5000    45      1
# 4          1         24      6000    77      0
# ..       ...        ...       ...   ...    ...
# 743       23          2       500    38      0
# 744       21          2       500    52      0
# 745       23          3       750    62      0
# 746       39          1       250    39      0
# 747       72          1       250    72      0
#
# [748 rows x 5 columns]>

# %%
df.columns
# Out:
# Index(['Recency', 'Frequency', 'Monetary', 'Time', 'Class'], dtype='object')

# %%
df.Frequency
# Out:
# 0      50
# 1      13
# 2      16
# 3      20
# 4      24
#        ..
# 743     2
# 744     2
# 745     3
# 746     1
# 747     1
# Name: Frequency, Length: 748, dtype: int64

# %%
df.dtypes
# Out:
# Recency      int64
# Frequency    int64
# Monetary     int64
# Time         int64
# Class        int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Recency      0
# Frequency    0
# Monetary     0
# Time         0
# Class        0
# dtype: int64

# %%
df
# Out:
#      Recency  Frequency  Monetary  Time  Class
# 0          2         50     12500    98      1
# 1          0         13      3250    28      1
# 2          1         16      4000    35      1
# 3          2         20      5000    45      1
# 4          1         24      6000    77      0
# ..       ...        ...       ...   ...    ...
# 743       23          2       500    38      0
# 744       21          2       500    52      0
# 745       23          3       750    62      0
# 746       39          1       250    39      0
# 747       72          1       250    72      0
#
# [748 rows x 5 columns]

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 743    False
# 744    False
# 745    False
# 746    False
# 747    False
# Length: 748, dtype: bool

# %%
df.describe()
# Out:
#           Recency   Frequency      Monetary        Time       Class
# count  748.000000  748.000000    748.000000  748.000000  748.000000
# mean     9.506684    5.514706   1378.676471   34.282086    0.237968
# std      8.095396    5.839307   1459.826781   24.376714    0.426124
# min      0.000000    1.000000    250.000000    2.000000    0.000000
# 25%      2.750000    2.000000    500.000000   16.000000    0.000000
# 50%      7.000000    4.000000   1000.000000   28.000000    0.000000
# 75%     14.000000    7.000000   1750.000000   50.000000    0.000000
# max     74.000000   50.000000  12500.000000   98.000000    1.000000

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748 entries, 0 to 747
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Recency    748 non-null    int64
#  1   Frequency  748 non-null    int64
#  2   Monetary   748 non-null    int64
#  3   Time       748 non-null    int64
#  4   Class      748 non-null    int64
# dtypes: int64(5)
# memory usage: 29.3 KB

# %%
corr = df.select_dtypes(include=np.number).corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm')
plt.title("Numeric Feature Correlation")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748 entries, 0 to 747
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Recency    748 non-null    int64
#  1   Frequency  748 non-null    int64
#  2   Monetary   748 non-null    int64
#  3   Time       748 non-null    int64
#  4   Class      748 non-null    int64
# dtypes: int64(5)
# memory usage: 29.3 KB
